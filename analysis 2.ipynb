# %%
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats

# %%
companies = pd.read_excel('Largest Companies in the World.xlsx')
companies.head()
# Out:
#    Global Rank                  Company  Sales ($billion)  Profits ($billion)  \
# 0            1                     ICBC             134.8                37.8
# 1            2  China Construction Bank             113.1                30.6
# 2            3           JPMorgan Chase             108.2                21.3
# 3            4         General Electric             147.4                13.6
# 4            5              Exxon Mobil             420.7                44.9
#
#    Assets ($billion)  Market Value ($billion) Country      Continent  \
# 0             2813.5                    237.3   China           Asia
# 1             2241.0                    202.0   China           Asia
# 2             2359.1                    191.4     USA  North America
# 3              685.3                    243.7     USA  North America
# 4              333.8                    400.4     USA  North America
#
#    Latitude   Longitude
# 0  35.86166  104.195397
# 1  35.86166  104.195397
# ...

# %%
companies_real = companies.drop(["Global Rank"], axis=1)
companies_real.head()
# Out:
#                    Company  Sales ($billion)  Profits ($billion)  \
# 0                     ICBC             134.8                37.8
# 1  China Construction Bank             113.1                30.6
# 2           JPMorgan Chase             108.2                21.3
# 3         General Electric             147.4                13.6
# 4              Exxon Mobil             420.7                44.9
#
#    Assets ($billion)  Market Value ($billion) Country      Continent  \
# 0             2813.5                    237.3   China           Asia
# 1             2241.0                    202.0   China           Asia
# 2             2359.1                    191.4     USA  North America
# 3              685.3                    243.7     USA  North America
# 4              333.8                    400.4     USA  North America
#
#    Latitude   Longitude
# 0  35.86166  104.195397
# 1  35.86166  104.195397
# 2  37.09024  -95.712891
# 3  37.09024  -95.712891
# 4  37.09024  -95.712891

# %%
sns.countplot(y="Continent", data=companies_real)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Continent'>

# %%
companies_real.describe()['Sales ($billion)']['mean']
# Out:
# 19.26590436590437

# %%
companies_real.describe()['Assets ($billion)']['mean']
# Out:
# 79.50779625779626

# %%
companies_real.describe()['Market Value ($billion)']['mean']
# Out:
# 19.558160083160082

# %%
forbes = pd.read_csv("./Forbes Top2000 2017.csv")
forbes.head()
# Out:
#    Unnamed: 0   Rank                  Company        Country  Sales  Profits  \
# 0         NaN      1                     ICBC          China  151.4     42.0
# 1         NaN      2  China Construction Bank          China  134.2     35.0
# 2         NaN      3       Berkshire Hathaway  United States  222.9     24.1
# 3         NaN      4           JPMorgan Chase  United States  102.5     24.2
# 4         NaN      5              Wells Fargo  United States   97.6     21.9
#
#    Assets  Market Value      Sector             Industry
# 0  3473.2         229.8  Financials          Major Banks
# 1  3016.6         200.5  Financials       Regional Banks
# 2   620.9         409.9  Financials  Investment Services
# 3  2513.0         306.6  Financials          Major Banks
# 4  1943.4         274.4  Financials          Major Banks

# %%
forbes_all = forbes.drop(["Unnamed: 0"], axis=1)
display(forbes_all)
# Out:
#        Rank                  Company        Country    Sales  Profits  Assets  \
# 0         1                     ICBC          China  151.400   42.000  3473.2
# 1         2  China Construction Bank          China  134.200   35.000  3016.6
# 2         3       Berkshire Hathaway  United States  222.900   24.100   620.9
# 3         4           JPMorgan Chase  United States  102.500   24.200  2513.0
# 4         5              Wells Fargo  United States   97.600   21.900  1943.4
# ...     ...                      ...            ...      ...      ...     ...
# 1995   1996                BEKB-BCBE    Switzerland    0.555    0.131    27.9
# 1996   1997        Fastighets Balder         Sweden    0.630    0.639    10.2
# 1997   1998      Akamai Technologies  United States    2.300    0.316     4.4
# 1998   1999                Oita Bank          Japan    0.523    0.071    27.9
# 1999   2000            Tech Mahindra          India    4.200    0.469     3.6
#
# ...

# %%
forbes_all.describe()['Sales']['mean']
# Out:
# 17.6645105

# %%
forbes_all.describe()['Profits']['mean']
# Out:
# 1.2407126

# %%
forbes_all.describe()['Assets']['mean']
# Out:
# 84.5335465

# %%
sns.scatterplot(x="Sales", y="Assets", data=forbes_all)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Assets'>

# %%
forbes_list = forbes_all.Company.values.tolist()

# %%
forbes_list
# Out:
# ['ICBC',
#  'China Construction Bank',
#  'Berkshire Hathaway',
#  'JPMorgan Chase',
#  'Wells Fargo',
#  'Agricultural Bank of China',
#  'Bank of America',
#  'Bank of China',
#  'Apple',
#  'Toyota Motor',
#  'AT&T',
#  'Citigroup',
#  'Exxon Mobil',
#  'General Electric',
#  'Samsung Electronics',
#  'Ping An Insurance Group',
#  'Wal-Mart Stores',
#  'Verizon Communications',
#  'Microsoft',
#  'Royal Dutch Shell',
#  'Allianz',
#  'China Mobile',
#  'BNP Paribas',
#  'Alphabet',
#  'China Petroleum & Chemical',
#  'Total',
#  'AXA Group',
#  'Daimler',
#  'Volkswagen Group',
#  'Mitsubishi UFJ Financial',
#  'Comcast',
#  'Johnson & Johnson',
#  'Banco Santander',
#  'Bank of Communications',
#  'Nestle',
#  'UnitedHealth Group',
#  'Nippon Telegraph & Tel',
#  'Itaú Unibanco Holding',
#  'Softbank',
#  'Gazprom',
#  'General Motors',
#  'China Merchants Bank',
#  'IBM',
#  'Royal Bank of Canada',
#  'Japan Post Holdings',
#  'Procter & Gamble',
#  'Pfizer',
# ...

# %%
companies_test = companies_real

# %%
for i, row in companies_test.iterrows():
    if row["Company"] in forbes_list:
        companies_test.drop(index=i, axis=0, inplace=True)
    companies_test.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-ad506bbf04b8> in <module>
#       1 for i, row in companies_test.iterrows():
#       2     if row["Company"] in forbes_list:
# ----> 3         companies_test.drop(index=i, axis=0, inplace=True)
#       4     companies_test.reset_index(drop=True, inplace=True)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
companies_test.head()

# %%
companies_real.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1052 entries, 0 to 1051
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Company                  1052 non-null   object
#  1   Sales ($billion)         1052 non-null   float64
#  2   Profits ($billion)       1052 non-null   float64
#  3   Assets ($billion)        1052 non-null   float64
#  4   Market Value ($billion)  1052 non-null   float64
#  5   Country                  1052 non-null   object
#  6   Continent                1052 non-null   object
#  7   Latitude                 1052 non-null   float64
#  8   Longitude                1052 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 74.1+ KB

# %%
companies_real.Country.value_counts()
# Out:
# USA                     305
# Japan                   117
# China                    73
# UK                       54
# India                    39
# South Korea              38
# France                   35
# Canada                   32
# Hong Kong                27
# Germany                  24
# Taiwan                   22
# Australia                22
# Brazil                   20
# Russia                   18
# Sweden                   16
# Spain                    16
# Italy                    16
# Singapore                13
# Ireland                  12
# The Netherlands          11
# Malaysia                 10
# South Africa             10
# Finland                   9
# Thailand                  9
# Mexico                    9
# United Arab Emirates      8
# Greece                    8
# Belgium                   8
# Denmark                   6
# Turkey                    6
# Bermuda                   6
# Qatar                     6
# Saudi Arabia              6
# ...

# %%
companies_real.Continent.value_counts()
# Out:
# Asia             385
# North America    353
# Europe           250
# South America     27
# Oceania           23
# Africa            14
# Name: Continent, dtype: int64

# %%
start_up = pd.read_csv("./List of 700 Unicorn Companies.csv")
start_up.head()
# Out:
#    Company name Valuation (in $B) Date Joined Country of origin  \
# 0     Bytedance              $140  04-07-2017             China
# 1        Stripe               $95   1/23/2014     United States
# 2        SpaceX               $74  12-01-2012     United States
# 3  Didi Chuxing               $62   3/31/2015             China
# 4        Klarna             $45.6  12-12-2011            Sweden
#
#             City                 Industry  \
# 0        Beijing  Artificial intelligence
# 1  San Francisco                  Fintech
# 2      Hawthorne                    Other
# 3        Beijing    Auto & transportation
# 4      Stockholm                  Fintech
#
#                                            Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# 1        Khosla Ventures, LowercaseCapital, capitalG
# 2  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 3  Matrix Partners, Tiger Global Management, Soft...
# 4  Institutional Venture Partners, Sequoia Capita...

# %%
start_ups = start_up.drop(["Date Joined", "Investors"], axis=1)
display(start_ups)
# Out:
#        Company name Valuation (in $B) Country of origin           City  \
# 0         Bytedance              $140             China        Beijing
# 1            Stripe               $95     United States  San Francisco
# 2            SpaceX               $74     United States      Hawthorne
# 3      Didi Chuxing               $62             China        Beijing
# 4            Klarna             $45.6            Sweden      Stockholm
# ..              ...               ...               ...            ...
# 703          Shippo                $1     United States  San Francisco
# 704  Thirty Madison                $1     United States       New York
# 705  LetsGetChecked                $1           Ireland         Dublin
# 706          VerbIT                $1            Israel       Tel Aviv
# 707            Aura                $1     United States     Burlington
#
#                                 Industry
# 0                Artificial intelligence
# ...

# %%
companies_real.to_csv("companies.csv")

# %%
forbes_all.to_csv("forbes.csv")

# %%
start_ups.to_csv("start.csv")
